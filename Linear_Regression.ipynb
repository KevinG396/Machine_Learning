# %% [markdown]
# # Linear Regression

# %% [markdown]
# ### Dataset

# %%
import numpy as np
from matplotlib import pyplot as plt

np.random.seed(42)
# Generate x values evenly spaced between 1 and 10
x = np.linspace(1, 10, 50)
# Generate random noise with a normal distribution (mean=0, std=1)
noise = np.random.normal(0, 1, 50)

y = 5*x + 15+noise
plt.scatter(x, y, label='Data Points')
plt.show()

# %% [markdown]
# ### Least Squares Line

# %%
x_mean = np.mean(x)
y_mean = np.mean(y)
beta_1 = np.sum((x - x_mean) * (y - y_mean)) / np.sum((x - x_mean) ** 2)
beta_0 = y_mean - beta_1 * x_mean
y_hat = beta_0 + beta_1 * x
residuals = y - y_hat
ssr = np.sum(residuals ** 2)

plt.scatter(x, y, label='Data Points')
plt.plot(x, y_hat, color='red', label='Least Squares Line')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
print(beta_0,beta_1)
print(f"Sum of Squares of Residuals: {ssr}")
# Out:
# 15.12886909163834 4.935574000564641
# Sum of Squares of Residuals: 41.257089755557914

# %% [markdown]
# ### Use Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x.reshape(-1, 1), y)

intercept = model.intercept_
slope = model.coef_[0]

y_hat_model = intercept + slope * x

plt.scatter(x, y, label='Data Points')
plt.plot(x, y_hat, color='red', label='Least Squares Line')
plt.plot(x, y_hat_model, color='orange', label='Linear Model')
plt.legend()
plt.show()

# Print the intercept and coefficient
print(f"Intercept: {intercept}")
print(f"Slope: {slope}")
# Out:
# Intercept: 15.128869091638332
# Slope: 4.935574000564642
